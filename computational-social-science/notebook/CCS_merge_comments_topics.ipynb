# %%
import pandas as pd

# %%
product_reviews = pd.read_csv('product_reviews_comments_FINAL.csv', delimiter='|', header=None)
product_reviews_topic = pd.read_csv('product_reviews_comments_topics_20250527_FINAL.csv', delimiter='|', header=None)

print(product_reviews)
print(product_reviews_topic)
# Out:
#                0                                       1  \
# 0     B0CLML6FM8                       Utile e ben fatto
# 1     B0CLML6FM8                                 attuale
# 2     B0CLML6FM8                   israele e palestinesi
# 3     B0CLML6FM8                        Molto articolato
# 4     B0CLML6FM8  Buono per una visione a volo d'uccello
# ...          ...                                     ...
# 3743  8807036525                              Leggetelo.
# 3744  8807036525                                      Ni
# 3745  8807036525                    Un'occasione mancata
# 3746  8807036525           Fantastico romanzo d'esordio!
# 3747  8807036525              libro "La strada giovane".
#
#                                                       2  \
# 0     E' uno dei resoconti piu' ordinati che abbia m...
# 1     Bel libro attuale e snocciola le problematiche...
# 2     interessante ma troppo denso di informazioni ,...
# ...

# %%
merged_df = pd.concat([product_reviews, product_reviews_topic], axis=1)
print(merged_df)
# Out:
#                0                                       1  \
# 0     B0CLML6FM8                       Utile e ben fatto
# 1     B0CLML6FM8                                 attuale
# 2     B0CLML6FM8                   israele e palestinesi
# 3     B0CLML6FM8                        Molto articolato
# 4     B0CLML6FM8  Buono per una visione a volo d'uccello
# ...          ...                                     ...
# 3743  8807036525                              Leggetelo.
# 3744  8807036525                                      Ni
# 3745  8807036525                    Un'occasione mancata
# 3746  8807036525           Fantastico romanzo d'esordio!
# 3747  8807036525              libro "La strada giovane".
#
#                                                       2  \
# 0     E' uno dei resoconti piu' ordinati che abbia m...
# 1     Bel libro attuale e snocciola le problematiche...
# 2     interessante ma troppo denso di informazioni ,...
# ...

# %%
merged_df.to_csv('product_reviews_comments_topic.csv', sep="|")

# %%
merged_df
# Out:
#                0                                       1  \
# 0     B0CLML6FM8                       Utile e ben fatto
# 1     B0CLML6FM8                                 attuale
# 2     B0CLML6FM8                   israele e palestinesi
# 3     B0CLML6FM8                        Molto articolato
# 4     B0CLML6FM8  Buono per una visione a volo d'uccello
# ...          ...                                     ...
# 3743  8807036525                              Leggetelo.
# 3744  8807036525                                      Ni
# 3745  8807036525                    Un'occasione mancata
# 3746  8807036525           Fantastico romanzo d'esordio!
# 3747  8807036525              libro "La strada giovane".
#
#                                                       2  \
# 0     E' uno dei resoconti piu' ordinati che abbia m...
# 1     Bel libro attuale e snocciola le problematiche...
# 2     interessante ma troppo denso di informazioni ,...
# ...
