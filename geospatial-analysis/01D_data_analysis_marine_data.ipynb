# %%
import geopandas as gpd

# %%
data_12NM = gpd.read_file('/home/enrique/github/data-science-unitn/geospatial-analysis/data/World_12NM_v4_20231025_gpkg/eez_12nm_v4.gpkg')
data_24NM = gpd.read_file('/home/enrique/github/data-science-unitn/geospatial-analysis/data/World_24NM_v4_20231025_gpkg/eez_24nm_v4.gpkg')
gpd_EEZ = gpd.read_file('/home/enrique/github/data-science-unitn/geospatial-analysis/data/World_EEZ_v12_20231025_gpkg/eez_v12.gpkg')

# %%
data_12NM.head()
# Out:
#    MRGID          GEONAME POL_TYPE  MRGID_TER1 TERRITORY1  MRGID_SOV1  \
# 0  49010    Belgian 12 NM     12NM          14    Belgium          14
# 1  49012   Albanian 12 NM     12NM        2153    Albania        2153
# 2  49013  Bulgarian 12 NM     12NM        2174   Bulgaria        2174
# 3  49014   Croatian 12 NM     12NM        2160    Croatia        2160
# 4  49015     Danish 12 NM     12NM        2157    Denmark        2157
#
#   SOVEREIGN1 ISO_TER1       X_1       Y_1  MRGID_EEZ  AREA_KM2 ISO_SOV1  \
# 0    Belgium      BEL   2.85822  51.32973       3293      1431      BEL
# 1    Albania      ALB  19.34000  40.82508       5670      5455      ALB
# 2   Bulgaria      BGR  28.23011  42.90228       5672      5340      BGR
# 3    Croatia      HRV  15.69979  43.39992       5673     18833      HRV
# 4    Denmark      DNK  11.00168  56.15969       5674     31929      DNK
#
#    UN_SOV1  UN_TER1                                           geometry
# 0       56     56.0  MULTIPOLYGON (((3.17182 51.34374, 3.1708 51.34...
# 1        8      8.0  MULTIPOLYGON (((20.00835 39.69182, 20.0081 39....
# 2      100    100.0  MULTIPOLYGON (((28.85445 43.70723, 28.85441 43...
# 3      191    191.0  MULTIPOLYGON (((16.57721 42.28324, 16.57567 42...
# 4      208    208.0  MULTIPOLYGON (((15.41648 55.47665, 15.41889 55...

# %%
data_12NM[data_12NM['TERRITORY1'] == 'Italy'].plot()
#data_12NM.crs
# Out:
# <Axes: >

# %%
data_24NM.head()
# Out:
#    MRGID          GEONAME POL_TYPE  MRGID_TER1 TERRITORY1  MRGID_SOV1  \
# 0  49243    Belgian 24 NM     24NM          14    Belgium          14
# 1  49245     German 24 NM     24NM        2101    Germany        2101
# 2  49246   Albanian 24 NM     24NM        2153    Albania        2153
# 3  49247  Bulgarian 24 NM     24NM        2174   Bulgaria        2174
# 4  49248   Croatian 24 NM     24NM        2160    Croatia        2160
#
#   SOVEREIGN1 ISO_TER1       X_1       Y_1  MRGID_EEZ  AREA_KM2 ISO_SOV1  \
# 0    Belgium      BEL   2.65644  51.48898       3293      1156      BEL
# 1    Germany      DEU   9.77441  54.47629       5669      7900      DEU
# 2    Albania      ALB  18.99066  40.90174       5670      3645      ALB
# 3   Bulgaria      BGR  28.53547  42.87690       5672      5044      BGR
# 4    Croatia      HRV  15.37676  43.39258       5673     14317      HRV
#
#    UN_SOV1  UN_TER1                                           geometry
# 0       56     56.0  MULTIPOLYGON (((2.30586 51.42951, 2.2866 51.46...
# 1      276    276.0  MULTIPOLYGON (((11.65639 54.37656, 11.65932 54...
# 2        8      8.0  MULTIPOLYGON (((19.30431 40.06083, 19.26442 40...
# 3      100    100.0  MULTIPOLYGON (((28.94532 43.16093, 28.93992 43...
# 4      191    191.0  MULTIPOLYGON (((17.53329 42.52311, 17.54152 42...

# %%
data_24NM[data_24NM['TERRITORY1'] == 'Italy'].plot()
# Out:
# <Axes: >

# %%
gpd_EEZ.head()
# Out:
#    MRGID                                            GEONAME  MRGID_TER1  \
# 0   8444  United States Exclusive Economic Zone (America...      8670.0
# 1   8379        British Exclusive Economic Zone (Ascension)      8620.0
# 2   8446  New Zealand Exclusive Economic Zone (Cook Isla...      8672.0
# 3   8389  Overlapping claim Falkland / Malvinas Islands:...      8623.0
# 4   8440  French Exclusive Economic Zone (French Polynesia)      8656.0
#
#             POL_TYPE  MRGID_SOV1                   TERRITORY1 ISO_TER1  \
# 0              200NM        2204               American Samoa      ASM
# 1              200NM        2208                    Ascension      SHN
# 2              200NM        2227                 Cook Islands      COK
# 3  Overlapping claim        2208  Falkland / Malvinas Islands      FLK
# 4              200NM          17             French Polynesia      PYF
#
#        SOVEREIGN1  MRGID_TER2  MRGID_SOV2  ... ISO_SOV1 ISO_SOV2 ISO_SOV3  \
# 0   United States         NaN         NaN  ...      USA     None     None
# 1  United Kingdom         NaN         NaN  ...      GBR     None     None
# 2     New Zealand         NaN         NaN  ...      NZL     None     None
# 3  United Kingdom      8623.0      2149.0  ...      GBR      ARG     None
# 4          France         NaN         NaN  ...      FRA     None     None
#
#    UN_SOV1  UN_SOV2 UN_SOV3 UN_TER1 UN_TER2  UN_TER3  \
# 0      840      NaN     NaN    16.0     NaN      NaN
# 1      826      NaN     NaN   654.0     NaN      NaN
# 2      554      NaN     NaN   184.0     NaN      NaN
# 3      826     32.0     NaN   238.0   238.0      NaN
# 4      250      NaN     NaN   258.0     NaN      NaN
#
#                                             geometry
# 0  MULTIPOLYGON (((-166.64112 -17.55527, -166.641...
# 1  MULTIPOLYGON (((-10.93328 -7.88745, -10.93324 ...
# 2  MULTIPOLYGON (((-159.27579 -5.80051, -158.3846...
# 3  MULTIPOLYGON (((-58.54196 -56.22782, -61.62049...
# 4  MULTIPOLYGON (((-135.9282 -7.8981, -135.92651 ...
#
# [5 rows x 32 columns]

# %%
gpd_EEZ[gpd_EEZ['SOVEREIGN1'] == 'Italy']
# Out:
#      MRGID                          GEONAME  MRGID_TER1 POL_TYPE  MRGID_SOV1  \
# 219   5682  Italian Exclusive Economic Zone      2133.0    200NM        2133
#
#     TERRITORY1 ISO_TER1 SOVEREIGN1  MRGID_TER2  MRGID_SOV2  ... ISO_SOV1  \
# 219      Italy      ITA      Italy         NaN         NaN  ...      ITA
#
#     ISO_SOV2 ISO_SOV3  UN_SOV1  UN_SOV2 UN_SOV3 UN_TER1 UN_TER2  UN_TER3  \
# 219     None     None      380      NaN     NaN   380.0     NaN      NaN
#
#                                               geometry
# 219  MULTIPOLYGON (((6.36944 41.51417, 6.93028 41.8...
#
# [1 rows x 32 columns]
