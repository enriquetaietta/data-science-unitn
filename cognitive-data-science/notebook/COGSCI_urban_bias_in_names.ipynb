# %%
import pandas as pd

df_mistral_male = pd.read_json("mistral_male_text_labelled.jsonl", lines=True)

# %%
len(df_mistral_male)
len(df_mistral_male[df_mistral_male['IDEOLOGY'] == 'FAR LEFT'])
OWNER_RESPONSE_LABELS = (df_mistral_male[df_mistral_male['IDEOLOGY'] == 'FAR LEFT'])['OWNER_RESPONSE_LABELS']

# %%
type(OWNER_RESPONSE_LABELS)
print(len(OWNER_RESPONSE_LABELS))
print(OWNER_RESPONSE_LABELS.apply(lambda x: x['overall_response'] == 'open').sum() / len(OWNER_RESPONSE_LABELS))
print(OWNER_RESPONSE_LABELS.apply(lambda x: x['overall_response'] == 'closed').sum() / len(OWNER_RESPONSE_LABELS))
print(OWNER_RESPONSE_LABELS.apply(lambda x: x['overall_response'] == 'open_positive').sum() / len(OWNER_RESPONSE_LABELS))
print(OWNER_RESPONSE_LABELS.apply(lambda x: x['overall_response'] == 'open_negative').sum() / len(OWNER_RESPONSE_LABELS))
print(OWNER_RESPONSE_LABELS.apply(lambda x: x['overall_response'] == 'open_demanding').sum() / len(OWNER_RESPONSE_LABELS))
# Out:
# 1728
# 0.2488425925925926
# 0.24363425925925927
# 0.1412037037037037
# 0.009837962962962963
# 0.35648148148148145

# %%
OWNER_RESPONSE_LABELS_mamadou = (  df_mistral_male[ (df_mistral_male['TENANT'] == 'Mamadou Diop') &  (df_mistral_male['CITY'] == 'MILAN;BRERA') ]  )['OWNER_RESPONSE_LABELS']

# %%
print(len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['overall_response'] == 'open').sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['overall_response'] == 'closed').sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['overall_response'] == 'open_positive').sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['overall_response'] == 'open_negative').sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['overall_response'] == 'open_demanding').sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['ethnic_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['ethnic_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['class_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_mamadou))
print(OWNER_RESPONSE_LABELS_mamadou.apply(lambda x: x['class_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_mamadou))
# Out:
# 72
# 0.16666666666666666
# 0.4861111111111111
# 0.16666666666666666
# 0.0
# 0.18055555555555555
# 0.4305555555555556
# 0.5694444444444444
# 0.5833333333333334
# 0.4166666666666667

# %%
OWNER_RESPONSE_LABELS_mohamed = (  df_mistral_male[ (df_mistral_male['TENANT'] == 'Mohamed Benhida') &  (df_mistral_male['CITY'] == 'MILAN;BRERA') & (df_mistral_male['IDEOLOGY'] == 'FAR RIGHT') ]  )['OWNER_RESPONSE_LABELS']

# %%
print(len(OWNER_RESPONSE_LABELS_mohamed))
print("Mohamed - open: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['overall_response'] == 'open').sum() / len(OWNER_RESPONSE_LABELS_mohamed)) )
print("Mohamed - closed: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['overall_response'] == 'closed').sum() / len(OWNER_RESPONSE_LABELS_mohamed)))
print("Mohamed - open_positive: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['overall_response'] == 'open_positive').sum() / len(OWNER_RESPONSE_LABELS_mohamed)))
print("Mohamed - open_negative: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['overall_response'] == 'open_negative').sum() / len(OWNER_RESPONSE_LABELS_mohamed)))
print("Mohamed - open_demanding: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['overall_response'] == 'open_demanding').sum() / len(OWNER_RESPONSE_LABELS_mohamed)))
print("Mohamed - ethnic_discrimination_true: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['ethnic_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_mohamed)))
print("Mohamed - ethnic_discrimination_false: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['ethnic_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_mohamed)))
print("Mohamed - class_discimination_true: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['class_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_mohamed)))
print("Mohamed - class_discrimination_false: " + str(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['class_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_mohamed)))


print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['ageism_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_mohamed))
print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['ageism_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_mohamed))

print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['gender_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_mohamed))
print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['gender_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_mohamed))

print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['urban_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_mohamed))
print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['urban_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_mohamed))

print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['demanding'] == "1").sum() / len(OWNER_RESPONSE_LABELS_mohamed))
print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['demanding'] == "2").sum() / len(OWNER_RESPONSE_LABELS_mohamed))
print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['demanding'] == "3").sum() / len(OWNER_RESPONSE_LABELS_mohamed))
print(OWNER_RESPONSE_LABELS_mohamed.apply(lambda x: x['demanding'] == "more").sum() / len(OWNER_RESPONSE_LABELS_mohamed))
# Out:
# 24
# Mohamed - open: 0.0
# Mohamed - closed: 0.8333333333333334
# Mohamed - open_positive: 0.0
# Mohamed - open_negative: 0.0
# Mohamed - open_demanding: 0.16666666666666666
# Mohamed - ethnic_discrimination_true: 0.8333333333333334
# Mohamed - ethnic_discrimination_false: 0.16666666666666666
# Mohamed - class_discimination_true: 0.4166666666666667
# Mohamed - class_discrimination_false: 0.5833333333333334
# 0.08333333333333333
# 0.9166666666666666
# 0.0
# 1.0
# 0.5416666666666666
# 0.4583333333333333
# 0.0
# 0.125
# 0.2916666666666667
# 0.20833333333333334

# %%
OWNER_RESPONSE_LABELS_giovanni = (  df_mistral_male[ (df_mistral_male['TENANT'] == 'Giovanni Rossi') &  (df_mistral_male['CITY'] == 'MILAN;BRERA') & (df_mistral_male['IDEOLOGY'] == 'FAR RIGHT') ]  )['OWNER_RESPONSE_LABELS']

# %%
print(len(OWNER_RESPONSE_LABELS_giovanni))
print("Giovanni Rossi - open: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['overall_response'] == 'open').sum() / len(OWNER_RESPONSE_LABELS_giovanni)) )
print("Giovanni Rossi - closed: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['overall_response'] == 'closed').sum() / len(OWNER_RESPONSE_LABELS_giovanni)))
print("Giovanni Rossi - open_positive: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['overall_response'] == 'open_positive').sum() / len(OWNER_RESPONSE_LABELS_giovanni)))
print("Giovanni Rossi - open_negative: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['overall_response'] == 'open_negative').sum() / len(OWNER_RESPONSE_LABELS_giovanni)))
print("Giovanni Rossi - open_demanding: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['overall_response'] == 'open_demanding').sum() / len(OWNER_RESPONSE_LABELS_giovanni)))
print("Giovanni Rossi - ethnic_discrimination_true: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['ethnic_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_giovanni)))
print("Giovanni Rossi - ethnic_discrimination_false: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['ethnic_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_giovanni)))
print("Giovanni Rossi - class_discimination_true: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['class_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_giovanni)))
print("Giovanni Rossi - class_discrimination_false: " + str(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['class_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_giovanni)))

print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['ageism_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_giovanni))
print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['ageism_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_giovanni))

print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['gender_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_giovanni))
print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['gender_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_giovanni))

print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['urban_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_giovanni))
print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['urban_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_giovanni))

print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['demanding'] == "1").sum() / len(OWNER_RESPONSE_LABELS_giovanni))
print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['demanding'] == "2").sum() / len(OWNER_RESPONSE_LABELS_giovanni))
print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['demanding'] == "3").sum() / len(OWNER_RESPONSE_LABELS_giovanni))
print(OWNER_RESPONSE_LABELS_giovanni.apply(lambda x: x['demanding'] == "more").sum() / len(OWNER_RESPONSE_LABELS_giovanni))
# Out:
# 24
# Giovanni Rossi - open: 0.0
# Giovanni Rossi - closed: 0.875
# Giovanni Rossi - open_positive: 0.041666666666666664
# Giovanni Rossi - open_negative: 0.041666666666666664
# Giovanni Rossi - open_demanding: 0.041666666666666664
# Giovanni Rossi - ethnic_discrimination_true: 0.2916666666666667
# Giovanni Rossi - ethnic_discrimination_false: 0.7083333333333334
# Giovanni Rossi - class_discimination_true: 0.75
# Giovanni Rossi - class_discrimination_false: 0.25
# 0.2916666666666667
# 0.7083333333333334
# 0.125
# 0.875
# 0.041666666666666664
# 0.9583333333333334
# 0.041666666666666664
# 0.20833333333333334
# 0.16666666666666666
# 0.25

# %%
df_mistral_female = pd.read_json("mistral_female_text_labelled.jsonl", lines=True)

# %%
OWNER_RESPONSE_LABELS_fatima = (  df_mistral_female[ (df_mistral_female['TENANT'] == 'Sara Esposito') ]  )['OWNER_RESPONSE_LABELS']

# %%
print(len(OWNER_RESPONSE_LABELS_fatima))
print("Sara Esposito - open: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['overall_response'] == 'open').sum() / len(OWNER_RESPONSE_LABELS_fatima)) )
print("Sara Esposito - closed: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['overall_response'] == 'closed').sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - open_positive: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['overall_response'] == 'open_positive').sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - open_negative: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['overall_response'] == 'open_negative').sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - open_demanding: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['overall_response'] == 'open_demanding').sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - ethnic_discrimination_true: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['ethnic_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - ethnic_discrimination_false: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['ethnic_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - class_discimination_true: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['class_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - class_discrimination_false: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['class_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - gender_discimination_true: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['gender_discrimination'] == True).sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - gender_discrimination_false: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['gender_discrimination'] == False).sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - demanding_1: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['demanding'] == "1").sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - demanding_2: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['demanding'] == "2").sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - demanding_3: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['demanding'] == "3").sum() / len(OWNER_RESPONSE_LABELS_fatima)))
print("Sara Esposito - demanding_more: " + str(OWNER_RESPONSE_LABELS_fatima.apply(lambda x: x['demanding'] == "more").sum() / len(OWNER_RESPONSE_LABELS_fatima)))
# Out:
# 864
# Sara Esposito - open: 0.3125
# Sara Esposito - closed: 0.33796296296296297
# Sara Esposito - open_positive: 0.10416666666666667
# Sara Esposito - open_negative: 0.011574074074074073
# Sara Esposito - open_demanding: 0.2337962962962963
# Sara Esposito - ethnic_discrimination_true: 0.09143518518518519
# Sara Esposito - ethnic_discrimination_false: 0.9085648148148148
# Sara Esposito - class_discimination_true: 0.5393518518518519
# Sara Esposito - class_discrimination_false: 0.46064814814814814
# Sara Esposito - gender_discimination_true: 0.017361111111111112
# Sara Esposito - gender_discrimination_false: 0.9826388888888888
# Sara Esposito - demanding_1: 0.010416666666666666
# Sara Esposito - demanding_2: 0.09375
# Sara Esposito - demanding_3: 0.5474537037037037
# Sara Esposito - demanding_more: 0.29282407407407407
